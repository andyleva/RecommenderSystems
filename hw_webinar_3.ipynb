# %%
### Домашнее задание №3 к курсу "Рекомендательные системы"

# %% [markdown]
# **Ожидание:**
# - Отправляем e-mail с топ-10 товарами, отсортированными по вероятности
#
# **Реальность:**
# - Чего хочет менеджер от рекомендательной системы? (рост показателя X на Y% за Z недель)
# - По-хорошему надо бы предварительно посчитать потенциальный эффект от рекоммендательной системы (Оценки эффектов у менеджера и у вас могут сильно не совпадать: как правило, вы знаете про данные больше)
# - А у нас вообще есть e-mail-ы пользователей? Для скольки %? Не устарели ли они?
# - Будем ли использовать СМС и push-уведомления в приложении? Может, будем печатать рекомендации на чеке после оплаты на кассе?
# - Как будет выглядеть e-mail? (решаем задачу топ-10 рекомендаций или ранжирования? И топ-10 ли?)
# - Какие товары должны быть в e-mail? Есть ли какие-то ограничения (только акции и т п)?
# - Сколько денег мы готовы потратить на привлечение 1 юзера? CAC - Customer Aquisition Cost. Обычно CAC = расходы на коммуникацию + расходы на скидки
# - Cколько мы хотим зарабатывать с одного привлеченного юзера?
# ---
# - А точно нужно сортировать по вероятности?
# <br>
# <i>не обязательно (применяем случайный метод), но практически всегда. все  зависит от того, что мы хотим показать пользователю.</i>
# - Какую метрику использовать?
# <br>
# <i>RMSE (сравнивает прогнозное значение с фактическим) или МАЕ</i>
# - Сколько раз в неделю отпрпавляем рассылку?
# <br>
# <i>от 1 раза, можно ежедневно, в заисимости от бизнес-требования</i>
# - В какое время отправляем рассылку?
# <br>
# <i>в любое. эффективность рассылок может определяться по а/б тесту</i>
# - Будем отправлять одному юзеру много раз наши рекоммендации. Как добиться того, чтобы они хоть немного отличались?
# <br>
# <i>заложить в алгоритм изменение рекомендации в зависимости акций, сезонности, текущих покупок</i>
# - Нужно ли, чтобы в одной рассылке были *разные* товары? Как определить, что товары *разные*? Как добиться того, чтобы они были разными?
# <br>
# <i>Желательно. Наличие категории товаров может служить разделением товаров.</i>
# - И многое другое:)
